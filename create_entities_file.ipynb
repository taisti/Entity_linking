# %%
# !pip install owlready2
from owlready2 import *
import csv
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# Loading an ontology from a local file:

# %%
onto = get_ontology("foodon.owl").load()

# %% [markdown]
# By `base_iri` attribute we can get the IRI of the ontology:

# %%
print(onto.base_iri)
# Out:
# http://purl.obolibrary.org/obo/foodon.owl/

# %%
f = open('food_product_entities.csv', 'w')
writer = csv.writer(f)

# %%
food_product = IRIS["http://purl.obolibrary.org/obo/FOODON_00001002"]
print(food_product)
textual_definition = IRIS["http://purl.obolibrary.org/obo/IAO_0000115"]
for c in food_product.descendants():
    if textual_definition in c.get_properties(c):
        print(textual_definition[c][-1])
        td = textual_definition[c][-1]
        print(c, c.label[0], td)
        writer.writerow([c, c.label[0], td])
    else:
        print(c, c.label[0], "There is no textual definition provided")
        writer.writerow([c, c.label[0], 'NONE'])
# Out:
# obo.FOODON_00001002
# obo.FOODON_03315163 vegetable juice (dried) There is no textual definition provided
# obo.NCBITaxon_69811 Leuciscus idus There is no textual definition provided
# obo.NCBITaxon_155067 Vimba vimba There is no textual definition provided
# obo.FOODON_03311515 jalapeno pepper (green) There is no textual definition provided
# obo.FOODON_03309172 white bass (raw) There is no textual definition provided
# obo.FOODON_03304981 frozen dairy dessert (nutritively sweetened) There is no textual definition provided
# obo.FOODON_03315961 fat-based dessert (energy reduced) There is no textual definition provided
# obo.FOODON_03316748 black currant nectar (non-pulpy) There is no textual definition provided
# obo.FOODON_03304550 paddy rice There is no textual definition provided
# obo.FOODON_03307669 orange beverage concentrate There is no textual definition provided
# obo.FOODON_03308343 american lobster (raw) There is no textual definition provided
# ...

# %%
f.close()
